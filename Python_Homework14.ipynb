# %% [markdown]
# ## Домашнее задание № 14. API and Web-scrapping.

# %% [markdown]
# ### Задание 1
#
# - [x] Будем парсить страницу со свежеми новостям на habr.com/ru/all/.
#
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# KEYWORDS = ['python', 'парсинг']
#
# Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: <дата> - <заголовок> - <ссылка>
#
# - [x] Дополнительная часть (необязательная)
#
#
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: <дата> - <заголовок> - <ссылка> - <текст_статьи>

# %%
# Импортируем необходимые для работы библиотеки:

import time
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
# Определяем набор ключевых слов для поиска статей
KEYWORDS = ['SQL','Python','Райффайзенбанк','BigData']
base_link = 'https://habr.com/ru/all/'

# Делаем get-запрос к основной странице для поиска и превращаем ее с помощью BS
req = requests.get(base_link)
soup = BeautifulSoup(req.text, 'html.parser')

# %%
# получаем список статей
posts = soup.find_all('article', class_='post')

# %%
# В статьях находим заголовки, чтобы найти ссылку для перехода в полнотекстовую статью

headers = list(map(lambda x: x.find('h2', class_='post__title'), posts))
headers[0]
# Out:
# <h2 class="post__title">
# <a class="post__title_link" href="https://habr.com/ru/post/530670/">Ядерная война, скорее всего, не приведёт к вымиранию человечества</a>
# </h2>

# %%
link_to_full = list(map(lambda x: x.find('a').get('href'), headers))
link_to_full
# Out:
# ['https://habr.com/ru/post/530670/',
#  'https://habr.com/ru/company/gitlab/blog/530666/',
#  'https://habr.com/ru/post/530668/',
#  'https://habr.com/ru/post/530658/',
#  'https://habr.com/ru/post/530654/',
#  'https://habr.com/ru/company/netologyru/blog/530650/',
#  'https://habr.com/ru/post/530638/',
#  'https://habr.com/ru/company/selectel/blog/530648/',
#  'https://habr.com/ru/company/jugru/blog/530584/',
#  'https://habr.com/ru/post/529962/',
#  'https://habr.com/ru/company/kaspersky/blog/530644/',
#  'https://habr.com/ru/post/530636/',
#  'https://habr.com/ru/post/528762/',
#  'https://habr.com/ru/company/ruvds/blog/529828/',
#  'https://habr.com/ru/post/530614/',
#  'https://habr.com/ru/company/otus/blog/530612/',
#  'https://habr.com/ru/company/habr_career/blog/530586/',
#  'https://habr.com/ru/company/skillfactory/blog/530594/',
#  'https://habr.com/ru/post/530418/',
#  'https://habr.com/ru/company/habr_career/blog/530598/']

# %%
# получаем ссылку на последнюю страницу и формируем набор страниц для парсинга
link_to_last = soup.find('a', title='Последняя страница').get('href')
print(link_to_last)
last_page_num = re.search('(page)(\d+)\/',link_to_last)
print(last_page_num.group(1),last_page_num.group(2))


pages_for_scrap = [base_link,]
for i in range(2, int(last_page_num.group(2))+1):
    pages_for_scrap.append(base_link + last_page_num.group(1) + str(i))
print(pages_for_scrap)
# Out:
# /ru/all/page50/
# page 50
# ['https://habr.com/ru/all/', 'https://habr.com/ru/all/page2', 'https://habr.com/ru/all/page3', 'https://habr.com/ru/all/page4', 'https://habr.com/ru/all/page5', 'https://habr.com/ru/all/page6', 'https://habr.com/ru/all/page7', 'https://habr.com/ru/all/page8', 'https://habr.com/ru/all/page9', 'https://habr.com/ru/all/page10', 'https://habr.com/ru/all/page11', 'https://habr.com/ru/all/page12', 'https://habr.com/ru/all/page13', 'https://habr.com/ru/all/page14', 'https://habr.com/ru/all/page15', 'https://habr.com/ru/all/page16', 'https://habr.com/ru/all/page17', 'https://habr.com/ru/all/page18', 'https://habr.com/ru/all/page19', 'https://habr.com/ru/all/page20', 'https://habr.com/ru/all/page21', 'https://habr.com/ru/all/page22', 'https://habr.com/ru/all/page23', 'https://habr.com/ru/all/page24', 'https://habr.com/ru/all/page25', 'https://habr.com/ru/all/page26', 'https://habr.com/ru/all/page27', 'https://habr.com/ru/all/page28', 'https://habr.com/ru/all/page29', 'https://habr.com/ru/all/page30', 'https://habr.com/ru/all/page31', 'https://habr.com/ru/all/page32', 'https://habr.com/ru/all/page33', 'https://habr.com/ru/all/page34', 'https://habr.com/ru/all/page35', 'https://habr.com/ru/all/page36', 'https://habr.com/ru/all/page37', 'https://habr.com/ru/all/page38', 'https://habr.com/ru/all/page39', 'https://habr.com/ru/all/page40', 'https://habr.com/ru/all/page41', 'https://habr.com/ru/all/page42', 'https://habr.com/ru/all/page43', 'https://habr.com/ru/all/page44', 'https://habr.com/ru/all/page45', 'https://habr.com/ru/all/page46', 'https://habr.com/ru/all/page47', 'https://habr.com/ru/all/page48', 'https://habr.com/ru/all/page49', 'https://habr.com/ru/all/page50']

# %%
# в full-статьях собираем необходимые данные

result_df = pd.DataFrame()
for article in link_to_full:
    subreq = requests.get(article)
    time.sleep(0.3)
    subsoup = BeautifulSoup(subreq.text, 'html.parser')
    # получаем полный текст статьи
    post_full_text = subsoup.find('div', class_='post__body post__body_full').text
    # проверяем на наличие ключевых слов
    if any([keyword.lower() in post_full_text.lower() for keyword in KEYWORDS]):
        # находим дату поста, заголовок и полный текст
        post_date = subsoup.find('span', class_='post__time').get('data-time_published')
        post_title = subsoup.find('span', class_='post__title-text').text
        res_string = {'post_date': post_date, 'post_title': post_title, 'URL': article, 'Full_Text': post_full_text}
        result_df = pd.concat([result_df, pd.DataFrame([res_string])])
result_df
# Out:
#            post_date                                         post_title  \
# 0  2020-11-30T16:23Z                           ESP32 в окружении VSCode
# 0  2020-11-30T15:30Z                           Программа SmartData 2020
# 0  2020-11-30T13:07Z  CTF-соревнования 2020 для «белых хакеров». Ста...
# 0  2020-11-30T12:58Z  Как разработать ансамбль Light Gradient Booste...
# 0  2020-11-30T11:44Z                        Макропроблема микросервисов
#
#                                                  URL  \
# 0                   https://habr.com/ru/post/530638/
# 0     https://habr.com/ru/company/jugru/blog/530584/
# 0      https://habr.com/ru/company/otus/blog/530612/
# 0  https://habr.com/ru/company/skillfactory/blog/...
# 0    https://habr.com/ru/company/mailru/blog/530528/
#
#                                            Full_Text
# 0  \nВ нескольких следующих статьях я хотел бы де...
# 0  \n\nМы уже рассказывали Хабру, что новая Smart...
# 0  \n\n\n\nВ декабре OTUS при поддержке VolgaCTF ...
# 0  \nВ преддверии старта нового потока курса «Маш...
# 0  \n\r\nВсего за 20 лет разработка ПО перешла от...

# %%
# %%time
KEYWORDS = ['SQL','Python','Райффайзенбанк','BigData']
# финальная сборка по всем страницам
result_df = pd.DataFrame()
for page in pages_for_scrap:
    mainreq = requests.get(page)
    time.sleep(0.3)
    mainsoup = BeautifulSoup(mainreq.text, 'html.parser')
    # получаем список постов
    posts = mainsoup.find_all('article', class_='post')
    # в постах берем заголовки
    headers = list(map(lambda x: x.find('h2', class_='post__title'), posts))
    # в заголовках находим ссылки на полные тексты статей:
    link_to_full = list(map(lambda x: x.find('a').get('href'), headers))
    # по ссылкам страницы переходим и ищем статьи, которые подойдут нам по ключевым словам
    for article in link_to_full:
        subreq = requests.get(article)
        time.sleep(0.3)
        subsoup = BeautifulSoup(subreq.text, 'html.parser')
        # получаем полный текст статьи
        post_full_text = subsoup.find('div', class_='post__body post__body_full').text
        # проверяем на наличие ключевых слов
        if any([keyword.lower() in post_full_text.lower() for keyword in KEYWORDS]):
            # находим дату поста, заголовок и полный текст
            post_date = subsoup.find('span', class_='post__time').get('data-time_published')
            post_title = subsoup.find('span', class_='post__title-text').text
            res_string = {'post_date': post_date, 'post_title': post_title, 'URL': article, 'Full_Text': post_full_text}
            result_df = pd.concat([result_df, pd.DataFrame([res_string])])
            
result_df
# Out:
# Wall time: 20min 32s
#             post_date                                         post_title  \
# 0   2020-11-30T19:15Z  Новые ограничения в использовании Docker Hub и...
# 0   2020-11-30T16:23Z                           ESP32 в окружении VSCode
# 0   2020-11-30T15:30Z                           Программа SmartData 2020
# 0   2020-11-30T13:07Z  CTF-соревнования 2020 для «белых хакеров». Ста...
# 0   2020-11-30T12:58Z  Как разработать ансамбль Light Gradient Booste...
# ..                ...                                                ...
# 0   2020-11-13T10:05Z            Релиз Apache Ignite 2.9.0 — что нового?
# 0   2020-11-13T06:30Z  Обзор операторов PostgreSQL для Kubernetes. Ча...
# 0   2020-11-12T16:00Z  Ультимативный гайд по собеседованию DevOps-инж...
# 0   2020-11-12T15:53Z  Hey, Google: умные устройства будут активирова...
# 0   2020-11-12T15:46Z               Оптимизация моделей в Tensorflow 1.x
#
#                                                   URL  \
# 0     https://habr.com/ru/company/gitlab/blog/530666/
# 0                    https://habr.com/ru/post/530638/
# 0      https://habr.com/ru/company/jugru/blog/530584/
# 0       https://habr.com/ru/company/otus/blog/530612/
# 0   https://habr.com/ru/company/skillfactory/blog/...
# ..                                                ...
# 0   https://habr.com/ru/company/sberbank/blog/527870/
# 0      https://habr.com/ru/company/flant/blog/527524/
# 0   https://habr.com/ru/company/rebrainme/blog/527...
# 0   https://habr.com/ru/company/selectel/blog/527788/
# 0                    https://habr.com/ru/post/527786/
#
#                                             Full_Text
# 0   \nНи для кого уже не новость, что начиная с 2 ...
# 0   \nВ нескольких следующих статьях я хотел бы де...
# 0   \n\nМы уже рассказывали Хабру, что новая Smart...
# 0   \n\n\n\nВ декабре OTUS при поддержке VolgaCTF ...
# 0   \nВ преддверии старта нового потока курса «Маш...
# ..                                                ...
# 0   \nApache Ignite – это высокопроизводительная р...
# 0   \n\n\r\nНа прошлую статью, где мы рассмотрели ...
# 0   \n\n\r\nЯ начал заниматься сетями еще в школе,...
# 0   \n\nPhoto by Cristian Cristian on Unsplash\n\r...
# 0   \nTensorflow, хотя и сдаёт свои позиции в иссл...
#
# [193 rows x 4 columns]

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   post_date   193 non-null    object
#  1   post_title  193 non-null    object
#  2   URL         193 non-null    object
#  3   Full_Text   193 non-null    object
# dtypes: object(4)
# memory usage: 7.5+ KB

# %% [markdown]
# ### Задание 2
#
# - [x] Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса Avast Hack Ckeck. Список email-ов задаем переменной в начале кода:
#
#
# EMAIL = [xxx@x.ru, yyy@y.com]
#
# В итоге должен формироваться датафрейм со столбцами: <почта> - <дата утечки> - <источник утечки> - <описание утечки>

# %%
EMAIL = ["xxx@x.ru", "yyy@y.com"]

# %%
import json
req_dict = ({"emailAddresses":EMAIL})
req_dict
# Out:
# {'emailAddresses': ['xxx@x.ru', 'yyy@y.com']}

# %%
header = {"Vaar-Version":"0","Vaar-Header-App-Product": "hackcheck-web-avast"}

# %%
req2 = requests.post('https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data', json=req_dict, headers=header)

# %%
raw_res = req2.json()

# %%
# получаем датафрейм с информацией по утечкам
breach_data = pd.DataFrame()
for key, value in raw_res['breaches'].items():
    res_string = {'breach_id': value['breachId'], 'breach_date': value['publishDate'], 'site': value['site'], 'description': value['description']}
    add_mail = ','.join(list(raw_res['data'][res_string['site']]))
    res_string.update({'mail':add_mail})
    breach_data = pd.concat([breach_data, pd.DataFrame([res_string])])
breach_data = breach_data.reset_index().drop(['index'],axis=1)
breach_data
# Out:
#     breach_id           breach_date              site  \
# 0       16613  2019-03-28T00:00:00Z  verifications.io
# 1       17609  2020-05-21T00:00:00Z            vk.com
# 2       17110  2020-01-03T00:00:00Z     azcentral.com
# 3       17670  2020-05-28T00:00:00Z       wishbone.io
# 4       13094  2017-11-04T00:00:00Z    myheritage.com
# 5       16768  2019-06-13T00:00:00Z         canva.com
# 6        3176  2017-02-14T00:00:00Z    parapa.mail.ru
# 7          41  2016-10-24T00:00:00Z       dropbox.com
# 8           2  2016-10-21T00:00:00Z      linkedin.com
# 9        3587  2017-03-01T00:00:00Z      rayli.com.cn
# 10      17009  2019-10-17T00:00:00Z         zynga.com
# 11         12  2016-10-29T00:00:00Z            vk.com
# 12          3  2016-10-21T00:00:00Z         adobe.com
# 13      13662  2018-02-18T00:00:00Z        netlog.com
# 14       3520  2017-03-15T00:00:00Z    globalreach.eu
# 15       3164  2017-02-14T00:00:00Z     cfire.mail.ru
# 16       2961  2017-01-31T00:00:00Z  cdprojektred.com
# 17         15  2016-10-23T00:00:00Z         imesh.com
# 18       3669  2017-03-24T00:00:00Z         youku.com
#
#                                           description                mail
# 0   Big data e-mail verification platform verifica...            xxx@x.ru
# 1   At some time in 2020, the Russian social netwo...            xxx@x.ru
# 2   At an unconfirmed date, online Arizona newspap...           yyy@y.com
# 3   In January 2020, the online poll website Wishb...           yyy@y.com
# 4   In October 2017, a customer database belonging...           yyy@y.com
# 5   In May 2019, graphic-design site Canva's datab...           yyy@y.com
# 6   In July and August 2016, two criminals execute...            xxx@x.ru
# 7   Cloud storage company Dropbox suffered a major...           yyy@y.com
# 8   In 2012, online professional networking platfo...           yyy@y.com
# 9   On an unconfirmed date, Chinese gossip site Ra...           yyy@y.com
# 10  In September 2019, the game developer Zynga wa...           yyy@y.com
# 11  Popular Russian social networking platform VKo...            xxx@x.ru
# 12  In October of 2013, criminals penetrated Adobe...  xxx@x.ru,yyy@y.com
# 13  Netlog (formerly known as Facebox and Bingbox)...           yyy@y.com
# 14  In 2016, Global Reach Technology's database wa...           yyy@y.com
# 15  In July and August of 2016, two criminals carr...            xxx@x.ru
# 16  In March 2016, CDProjektRed.com.com's forum da...            xxx@x.ru
# 17  In June 2016, a cache of over 51 million user ...  xxx@x.ru,yyy@y.com
# 18  Youku is a large Chinese video content company...           yyy@y.com

# %% [markdown]
# ### Задание 3
#
# - [ ] Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте. Документация к API VK: https://vk.com/dev/methods , вам поможет метод wall.get
#
#
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>

# %%
url = 'https://api.vk.com/method/wall.get?'
group = 'netology'
token = ''
VERSION = '5.126'
SLEEP = 0.33

# %%
params = {
    'domain': group,
    'access_token': token,
    'v': VERSION,
    'count': 50
}

# %%
vk_posts = requests.get(url,params)
raw = vk_posts.json()['response']['items']
from datetime import datetime

finalta = pd.DataFrame()
for post in raw:
    post_date = datetime.fromtimestamp(post['date'])
    full_text = post['text']
    df_row = {'post_date':post_date.strftime('%Y-%m-%d %H:%M:%S'), 'post_text': full_text}
    finalta = pd.concat([finalta, pd.DataFrame([df_row])])
finalta.reset_index()
# Out:
#     index            post_date  \
# 0       0  2020-11-30 11:00:10
# 1       0  2020-12-04 18:36:00
# 2       0  2020-12-04 10:46:00
# 3       0  2020-12-03 17:38:00
# 4       0  2020-12-03 10:46:00
# 5       0  2020-12-02 16:35:02
# 6       0  2020-12-02 10:23:00
# 7       0  2020-12-01 17:51:00
# 8       0  2020-12-01 10:23:00
# 9       0  2020-11-30 16:53:00
# 10      0  2020-11-30 10:07:00
# 11      0  2020-11-29 12:27:00
# 12      0  2020-11-28 17:28:00
# 13      0  2020-11-28 14:28:00
# 14      0  2020-11-28 10:23:00
# 15      0  2020-11-27 17:14:00
# 16      0  2020-11-27 10:27:00
# 17      0  2020-11-26 17:31:00
# 18      0  2020-11-26 11:27:00
# 19      0  2020-11-25 16:05:12
# 20      0  2020-11-25 10:31:00
# 21      0  2020-11-24 17:43:00
# 22      0  2020-11-24 10:22:00
# 23      0  2020-11-23 17:04:00
# 24      0  2020-11-23 10:18:00
# 25      0  2020-11-22 16:22:00
# 26      0  2020-11-22 11:28:00
# 27      0  2020-11-21 15:22:00
# 28      0  2020-11-21 11:22:00
# 29      0  2020-11-20 17:36:00
# 30      0  2020-11-20 10:28:00
# 31      0  2020-11-19 17:42:00
# 32      0  2020-11-19 10:34:00
# 33      0  2020-11-18 16:25:04
# 34      0  2020-11-18 10:48:00
# 35      0  2020-11-17 17:35:00
# 36      0  2020-11-17 11:09:00
# 37      0  2020-11-16 17:48:00
# 38      0  2020-11-16 10:22:00
# 39      0  2020-11-15 16:17:00
# 40      0  2020-11-15 11:57:00
# 41      0  2020-11-14 10:22:00
# 42      0  2020-11-13 17:11:00
# 43      0  2020-11-13 10:33:00
# 44      0  2020-11-12 18:18:00
# 45      0  2020-11-12 10:54:00
# 46      0  2020-11-11 16:56:00
# 47      0  2020-11-11 10:32:00
# 48      0  2020-11-10 17:36:00
# 49      0  2020-11-10 15:30:00
#
#                                             post_text
# 0   В воздухе уже витает дух Нового года, а мы уст...
# 1   Еженедельный Giveaway, тысячи фолловеров из ра...
# 2   Таргетолог, копирайтер, бренд-менеджер, сммщик...
# 3   Поиск работы — волнительный процесс. \n \nПрои...
# 4   Карьера сегодня — не прямой и понятный путь из...
# 5   У нас сегодня Нето-викторина 🤩\n\nМы подготови...
# 6   🔥 19 декабря пройдёт бесплатная онлайн-конфере...
# 7   С тире или без? А может, дефис поставить?\n\nР...
# 8   Что надо знать и уметь, чтобы работать с данны...
# 9   📆 Составляем адвент-календарь взрослого челове...
# 10  🔥 Запустили бесплатный курс «Как перенести сво...
# 11  Неопределённость, непредсказуемые ситуации, ре...
# 12  Онлайн-мероприятия декабря: конференции для ди...
# 13  Онлайн-курсы становятся всё популярнее, рынок ...
# 14  Собрали статьи, которые помогут сделать работу...
# 15  Эффективность работы сммщика зависит не только...
# 16  Что нужно знать для старта в Data Science, зач...
# 17  Каждый день мы принимаем десятки решений. От н...
# 18  Ставьте палец вверх и переходите по ссылке в о...
# 19  Разыгрываем 10 доступов к библиотеке видеокурс...
# 20  30 ноября стартует бесплатный курс «Основы HTM...
# 21  Резюме без сопроводительного письма открывает ...
# 22  Как выбрать тему для статьи, побороть страх чи...
# 23  И мы не устояли перед магией Чёрной пятницы — ...
# 24  🤖 Запустили бесплатный курс «Профессии в Data ...
# 25  *партнёрский пост*\n\nНедавно на SEOnews.ru вы...
# 26  Как себя чувствует человек, существующий в фор...
# 27  *партнёрский пост* \n \nС 11 по 13 декабря сос...
# 28  Вам точно стоит попробовать Python, если вы ни...
# 29  В эфире #пятничнаябеседка. Здесь мы обсуждаем,...
# 30  Разбираемся с основами HTML и CSS и выбираем н...
# 31  Если на собеседовании можно взять красноречием...
# 32  Что такое талант? Мнения разделились. Избитый ...
# 33  Холода всё ближе, хочется закутаться в плед с ...
# 34  Чтобы поселиться в Париже, желательно выучить ...
# 35  Нужны ли кавычки в словосочетаниях: текст с из...
# 36  Что нужно для прохождения стажировки в иностра...
# 37  Есть крупный партнёр, отличная идея спецпроект...
# 38  Проект или продукт без менеджера — это дрова б...
# 39  *партнёрский пост*\n\nНаши друзья, Утконос ОНЛ...
# 40  Собрали книги об искусстве работы с текстами: ...
# 41  Ду ю спик инглиш? 👩‍🏫 \nСобрали статьи, которы...
# 42  Чтобы эта пятница, 13-е, прошла без неожиданно...
# 43  Какое направление в маркетинге выбрать, чем та...
# 44  С какими сложностями в работе сталкиваются ана...
# 45  «Лучше сделать как-нибудь, но сейчас, чем идеа...
# 46  11 ноября — День борьбы с кибербуллингом. \n \...
# 47  Если интернет сравнить с экзотической страной,...
# 48  У Google Документов много плюсов: можно правит...
# 49  Карьера в 21 веке перестала быть прямым маршру...
